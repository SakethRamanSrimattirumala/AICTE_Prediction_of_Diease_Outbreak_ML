# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now we are importing the important packages for the project

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm 
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and analysis

# %%
#Loading the dataset into a pnadas dataframe
diabetes_dataset = pd.read_csv('../Datasets/diabetes.csv')

# %%
# Separate the dataset into two groups based on the 'Outcome' column
outcome_0 = diabetes_dataset[diabetes_dataset['Outcome'] == 0]
outcome_1 = diabetes_dataset[diabetes_dataset['Outcome'] == 1]

# Undersample the groups
outcome_0_undersampled = outcome_0.sample(n=300, random_state=42)
outcome_1_undersampled = outcome_1.sample(n=268, random_state=42)

# Combine the undersampled groups into a new DataFrame
undersampled_diabetes_dataset = pd.concat([outcome_0_undersampled, outcome_1_undersampled])

# Shuffle the combined DataFrame
undersampled_diabetes_dataset = undersampled_diabetes_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Display the new DataFrame
print(undersampled_diabetes_dataset['Outcome'].value_counts())
# Out:
# Outcome
# 0    300
# 1    268
# Name: count, dtype: int64

# %%
#printing the first 5 rows of the dataset
undersampled_diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      164             82             43       67  32.8
# 1            5      126             78             27       22  29.6
# 2            6      129             90              7      326  19.6
# 3            2       92             52              0        0  30.1
# 4            3      176             86             27      156  33.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.341   50        0
# 1                     0.439   40        0
# 2                     0.582   60        0
# 3                     0.141   22        0
# 4                     1.154   52        1

# %%
#getting the rows and columns of the dataset
undersampled_diabetes_dataset.shape
# Out:
# (568, 9)

# %%
#getting the statistical information of the dataset
undersampled_diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   568.000000  568.000000     568.000000     568.000000  568.000000
# mean      4.049296  124.227113      69.482394      20.875000   80.056338
# std       3.443835   32.919969      19.362404      16.200579  115.266964
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000  101.750000      64.000000       0.000000    0.000000
# 50%       3.000000  120.000000      72.000000      24.000000   20.000000
# 75%       6.000000  145.250000      80.000000      33.000000  130.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  568.000000                568.000000  568.000000  568.000000
# mean    32.563380                  0.496188   33.991197    0.471831
# std      7.809805                  0.351743   11.632903    0.499646
# min      0.000000                  0.084000   21.000000    0.000000
# 25%     28.000000                  0.254000   25.000000    0.000000
# 50%     32.600000                  0.394500   31.000000    0.000000
# 75%     36.800000                  0.658500   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
undersampled_diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    300
# 1    268
# Name: count, dtype: int64

# %%
undersampled_diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.320000  109.013333      68.283333      19.723333   61.940000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.259333                   0.44767  31.243333
# 1        35.142537                   0.55050  37.067164

# %%
#seperating data and the labels
x = undersampled_diabetes_dataset.drop(columns='Outcome', axis=1)
y = undersampled_diabetes_dataset['Outcome']

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      164             82             43       67  32.8
# 1            5      126             78             27       22  29.6
# 2            6      129             90              7      326  19.6
# 3            2       92             52              0        0  30.1
# 4            3      176             86             27      156  33.3
#
#    DiabetesPedigreeFunction  Age
# 0                     0.341   50
# 1                     0.439   40
# 2                     0.582   60
# 3                     0.141   22
# 4                     1.154   52

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# Train Test Split

# %%
x_train, x_test, y_train ,y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape,x_train.shape, x_test.shape)
# Out:
# (568, 8) (454, 8) (114, 8)

# %%
x_train.head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 175           11      138             74             26      144  36.1
# 529            0       84             82             31      125  38.2
# 27             1      128             82             17      183  27.5
# 565            6      151             62             31      120  35.5
# 481            9      156             86              0        0  24.8
#
#      DiabetesPedigreeFunction  Age
# 175                     0.557   50
# 529                     0.233   23
# 27                      0.115   22
# 565                     0.692   28
# 481                     0.230   53

# %% [markdown]
# Training the Model

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation and Accuracy Score

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.7577092511013216

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)
print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on test data :  0.7543859649122807

# %% [markdown]
# Making a Predective system

# %%
input_data = (1, 85, 66, 29, 0, 26.6, 0.351, 31)
#converting the input data into numpy array
input_data_as_numpy_array = np.asarray(input_data)
#reshaping the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [0]
# The person is not diabetic
# /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Saving the trained model

# %%
pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
filename = 'diabetes_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
#loading the saved model 
loaded_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
input_data = (1, 85, 66, 29, 0, 26.6, 0.351, 31)
#converting the input data into numpy array
input_data_as_numpy_array = np.asarray(input_data)
#reshaping the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = loaded_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [0]
# The person is not diabetic
# /Users/sakethramansrimattirumala/Desktop/GITAM/Third Year/SEM 6/Personal/AI project version 2_undersample/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
#the data fields of the dataset x
for column in x.columns:
  print(column)
# Out:
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age
